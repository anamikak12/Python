# %%
#third element and third element from last of a tuple
n=(2,4,3,5,6,7)
print("3rd element:",n[2])
print("3rd element from last:",n[-3])
# Out:
# 3rd element: 3
# 3rd element from last: 5

# %%
#find avg of all items in that tuple
n=input("enter a sequence of numbers:")
n1=tuple(map(float,number.split(",")))
average= sum(n1)/ len(n1)
print("tuple:",n1)
print("average:",average)
# Out:
# enter a sequence of numbers:3,5,4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 #find avg of all items in that tuple
#       2 n=input("enter a sequence of numbers:")
# ----> 3 n1=tuple(map(float,numbers.split(",")))
#       4 average= sum(n1)/ len(n1)
#       5 print("tuple:",n1)
#
# AttributeError: 'tuple' object has no attribute 'split'
