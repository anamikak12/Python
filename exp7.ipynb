# %%
#print out all colors from colors set1 not  contained in color set2
colorset1= {"blue","black","red","yellow","violet"}
colorset2= {"blue","black","orange","purple"}
colors=colorset1-colorset2
print("colors is not contain in color set2: ",colors)
# Out:
# colors is not contain in color set2:  {'violet', 'yellow', 'red'}

# %%
#print all colors from set1 and set2
colorset1= {"blue","black","red","yellow","violet"}
colorset2= {"blue","black","orange","purple"}
colors=colorset1|colorset2
print("all colors from colorset1 and colorset2:",colors)
# Out:
# all colors from colorset1 and colorset2: {'yellow', 'black', 'red', 'violet', 'orange', 'purple', 'blue'}
