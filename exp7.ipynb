# %%
#colors in set1 but not in set2
set1=set(input("enter colors in set1:").split(","))
set2=set(input("enter colors in set2:").split(","))
print("set1:",set1)
print("set2:",set2)
print("the colors in set1 but not in set2:",set1.difference(set2))
# Out:
# enter colors in set1: blue,red,green,orange
# enter colors in set2: purple,red,yellow,olivegreen
# set1: {'blue', 'red', 'orange', 'green'}
# set2: {'yellow', 'purple', 'red', 'olivegreen'}
# the colors in set1 but not in set2: {'blue', 'green', 'orange'}

# %%
#display all the colors in set1 and set2
s1=set(input("enter colors in set1:").split(","))
s2=set(input("enter colors in set2:").split(","))
print("set1=",s1)
print("set2=",s2)
print("the colors in both sets are=",s1.union(s2))
# Out:
# enter colors in set1: yellow,red,blue
# enter colors in set2: green,black,red,orange
# set1= {'yellow', 'blue', 'red'}
# set2= {'black', 'green', 'red', 'orange'}
# the colors in both sets are= {'black', 'green', 'red', 'yellow', 'blue', 'orange'}
